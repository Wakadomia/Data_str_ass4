# %% [markdown]
# <span style="font-size: 25px">**leetcode 225**

# %%
import queue

class MyStack(object):

    def __init__(self):
        self.q1 = queue.Queue()
        self.q2 = queue.Queue()

    def push(self, x):
        """
        :type x: int
        :rtype: None
        """
        self.q2.put(x)
        while not self.q1.empty():
            self.q2.put(self.q1.get())
        self.q1, self.q2 = self.q2, self.q1

    def pop(self):
        """
        :rtype: int
        """
        return self.q1.get()

    def top(self):
        """
        :rtype: int
        """
        top_element = None
        size = self.q1.qsize()
        for _ in range(size):
            top_element = self.q1.get()
            self.q2.put(top_element)
        self.q1, self.q2 = self.q2, self.q1
        return top_element

    def empty(self):
        """
        :rtype: bool
        """
        return self.q1.empty()

# %% [markdown]
# <span style="font-size: 25px">**leetcode 232**

# %%
class MyQueue(object):

    def __init__(self):
        self.input_stack = []
        self.output_stack = []

    def push(self, x):
        self.input_stack.append(x)

    def pop(self):
        self._transfer_if_needed()
        return self.output_stack.pop()

    def peek(self):
        self._transfer_if_needed()
        return self.output_stack[-1]

    def empty(self):
        return not self.input_stack and not self.output_stack

    def _transfer_if_needed(self):
        if not self.output_stack:
            while self.input_stack:
                self.output_stack.append(self.input_stack.pop())

# %% [markdown]
# <span style="font-size: 25px">**Queue**

# %%
#1.
class ListQueue:
	def __init__(self):
    	self.__queue = []
    
    def enqueue(self, item):
    	self.__queue.insert(0, item)
        
    def dequeue(self):
    	return self.__queue.pop()
        
    def front(self):
    	if self.__queue.is_empty():
        	return None
        else:
        	return self.__queue[len(self.__queue) - 1]
            
    def is_empty(self) -> bool:
    	return not bool(self.__queue)
        
    def dequeue_all(self):
    	self.__queue.clear()


#2. 
def is_in_set(string: String) -> bool:
	q = ListQueue()
    index = 0
    while string[index] != '$':
    	q.enqueue(string[index])
        index += 1
    index += 1
    while index < len(string):
    	if q.dequeue() != string[index]:
        	return False
        else:
        	index += 1
    return True


#3.
def copy_linked_queue(a: LinkedQueue, b: LinkedQueue):
	b.dequeue_all()
    temp_queue = LinkedQueue()
    while not a.is_empty():
    	temp_queue.enqueue(a.dequeue())
    while not temp_queue.is_empty():
    	a.enqueue(temp_queue.front())
        b.enqueue(temp_queue.dequeue())


#4.
def push(q1: LinkedQueue, q2: LinkedQueue, item):
	q2.dequeue_all()
	while not q1.is_empty():
    	q2.enqueue(q1.dequeue())
    q1.enqueue(item)
    while not q2.is_empty():
    	q1.enqueue(q2.dequeue())
        

def pop(q1: LinkedQueue, q2: LinkedQueue):
	q2.dequeue_all()
    count = 0
	while not q1.is_empty():
    	q2.enqueue(q1.dequeue())
        count += 1
    while _ in range(count - 1):
    	q1.enqueue(q2.dequeue())
    return q2.dequeue()


#5.
def enqueue(s1: LinkedStack, s2: LinkedStack, item):
	s2.pop_all()
    while not s1.is_empty():
    	s2.push(s1.pop())
    s1.push(item)
    while not s2.is_empty():
    	s1.push(s2.pop())

def dequeue(s1: LinkedStack, s2: LinkedStack):
	s2.pop_all()
    while not s1.is_empty():
    	s2.push(s1.pop())
    ret_item = s2.pop()
    while not s2.is_empty():
    	s1.push(s2.pop())
    return ret_item


#6. 
구현하고자 하는 Deque는 단방향원형리스트를 기반으로 하고, 이 Deque의 front는 리스트의 맨 앞이며 tail은 리스트의 맨 끝으로 한다.
enqueue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(1)이므로 수행 위치에 상관없이 enqueue()의 수행 시간은 Θ(1)이다.
dequeue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(1)이므로 수행 위치에 상관없이 dequeue()의 수행 시간은 Θ(1)이다.


#7. 
enqueue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(n)이다. 따라서 enqueue()의 수행 시간은 최악의 경우를 고려해 Θ(n)이다.
dequeue()의 수행시간은 Deque의 front에서 수행할 시 Θ(1), Deque의 tail에서 수행할 시 Θ(n)이다. 따라서 dequeue()의 수행 시간은 최악의 경우를 고려해 Θ(n)이다.

    
#.8
class ListDeque:
    def __init__(self):
    	self.__queue = []
    
    def enqueue(self, item):
        self.__queue.append(item)
    
    def dequeue(self):
    	return self.__queue.pop(0)
    
    def push(self, item):
    	self.__queue.insert(0, item)
    
    def pop(self):
    	return self.__queue.pop(len(self.__queue) - 1)
    
    def front(self):
    	if self.is_empty():
        	return None
        else:
        	return self.__queue[0]
    
    def rear(self):
    	if self.is_empty():
        	return None
    	else:
        	return self.__queue[len(self.__queue) - 1]
    
    def is_empty(self):
    	return not bool(self.__queue)
    
    def deque_all(self):
    	self.__queue.clear()
    
    def print_deque(self):
    	print("Dequeue from front:", end = ' ')
        for index in range(len(self.__queue)):
        	print(self.__queue[index], end = ' ')
        print()
# Out:
#   File <tokenize>:6
#     def enqueue(self, item):
#     ^
# IndentationError: unindent does not match any outer indentation level
